# %% [markdown]
# <a href="https://colab.research.google.com/github/ruiskaunokki/stepik/blob/main/6_9_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install pandas
import pandas as pd

# %%
df = pd.read_csv(r'https://stepik.org/media/attachments/lesson/345422/torg.csv', sep=';')
df
# Out:
#      IE_XML_ID               IE_NAME IP_PROP30  IP_PROP31 IP_PROP32  \
# 0          179  Штаны Полосатый Рейс    purple        NaN         L
# 1          181  Штаны Полосатый Рейс    purple        NaN        XL
# 2          182  Штаны Полосатый Рейс    purple        NaN        XS
# 3          183  Штаны Полосатый Рейс    purple        NaN         M
# 4          184  Штаны Полосатый Рейс    purple        NaN         S
# ..         ...                   ...       ...        ...       ...
# 270        639    Ремень Грубая Кожа     brown        NaN         L
# 271        641    Ремень Грубая Кожа     brown        NaN        XL
# 272        642    Ремень Грубая Кожа     brown        NaN        XS
# 273        643    Ремень Грубая Кожа     brown        NaN         M
# 274        644    Ремень Грубая Кожа     brown        NaN         S
#
#      CP_QUANTITY  CR_PRICE_1_USD
# 0             99           29.06
# 1            100           29.06
# 2            100           29.06
# ...

# %%
df.groupby('IP_PROP32').sum().sort_values('CP_QUANTITY')
# Out:
#            IE_XML_ID  IP_PROP31  CP_QUANTITY  CR_PRICE_1_USD
# IP_PROP32
# M              17003        0.0         4198         1068.71
# S              17047        0.0         4198         1068.71
# XS             16959        0.0         4299         1068.71
# L              16827        0.0         4397         1068.71
# XL             16915        0.0         4399         1068.71
