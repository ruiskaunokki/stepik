# %% [markdown]
# <a href="https://colab.research.google.com/github/ruiskaunokki/stepik/blob/main/6_9_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/dataset_345422_8 (5).txt', sep=';')
df
# Out:
#      IE_XML_ID                         IE_NAME IP_PROP30  IP_PROP31 IP_PROP32  \
# 0          373        Футболка Женская Чистота     white        NaN        XS
# 1          246          Штаны Цветочная Поляна     green        NaN         L
# 2          596                   Ремень Радуга     green        NaN        XL
# 3          562                   Ремень Радуга    purple        NaN        XS
# 4          527               Туфли Ультра Лайн     jeans       39.0       NaN
# ..         ...                             ...       ...        ...       ...
# 195        481  Домашние Тапочки Любимый Спорт     brown       38.0       NaN
# 196        260      Платье Модница на Прогулке      blue        NaN         S
# 197        518           Туфли Полет Валькирии      blue       39.0       NaN
# 198        319     Нижнее белье Интимный Вечер     black        NaN        XS
# 199        286              Платье Красная Фея       red        NaN         M
#
#      CP_QUANTITY  CR_PRICE_1_USD
# ...

# %%
df1 = df[['IP_PROP30', 'IP_PROP32', 'CP_QUANTITY', 'CR_PRICE_1_USD']]
px = df1.loc[df['IP_PROP30'] == 'pink']
px = px.loc[df['IP_PROP32'] == 'XL']
px
# Out:
#     IP_PROP30 IP_PROP32  CP_QUANTITY  CR_PRICE_1_USD
# 166      pink        XL          100            5.67

# %%
n = 0
for a in df.values:
  if a[2] == 'pink' and a[4] == 'XL':
    n += a[5] * a[6]
n
# Out:
# 567.0
